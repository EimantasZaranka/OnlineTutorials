# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
PATH = '/content/drive/MyDrive/Datasets/seaborn_tut/'

# %%
ds = pd.read_csv(PATH + 'marketing.csv')
ds.head()
# Out:
#          Date  Week  Week_ID  ...  Revenue  Marketing Spend           Promo
# 0  09/11/2020    46       34  ...      465          651.375        No Promo
# 1  10/11/2020    46       34  ...    10386         1298.250   Promotion Red
# 2  11/11/2020    46       34  ...    12475         1559.375  Promotion Blue
# 3  12/11/2020    46       34  ...    11712         1801.750        No Promo
# 4  13/11/2020    46       34  ...    10000         2614.500        No Promo
#
# [5 rows x 11 columns]

# %% [markdown]
# # 2. Line graph

# %%
ax = sns.lineplot(x = 'Week_ID', y = 'Revenue', data=ds)
# Note: error bands show the confidence interval

# %%
ax = sns.lineplot(x='Week_ID', y='Revenue', data=ds, hue='Promo')

# %%
ax = sns.lineplot(x='Week_ID', y='Revenue', data=ds, hue='Promo', style='Promo')

# %%
sns.set(rc={f'figure.figsize':(12,10)})

# %%
ax = sns.lineplot(x='Week_ID', y='Revenue', data=ds, hue='Promo', style='Promo', ci=False)

# %%
ax = sns.lineplot(x='Week_ID', y='Revenue', data=ds, hue='Promo', style='Promo', ci=False, markers=True)

# %%
ax = sns.lineplot(x='Month_ID', y='Revenue', data=ds, hue='Promo', style='Promo', ci=False, markers=True)

# %%
ax = sns.lineplot(x='Month_ID', y='Revenue', data=ds, hue='Day_Name', style='Promo', ci=False, markers=True)

# %%
ax = sns.lineplot(x='Year', y='Revenue', data=ds, hue='Day_Name', style='Promo', ci=False, markers=True)

# %% [markdown]
# # 3. Bar Plots

# %%
ax = sns.barplot(x='Month_ID', y='Revenue', data=ds)
#lines are confidence itnerval

# %%
ds[['Revenue','Month_ID']].groupby('Month_ID').agg({'Revenue':'mean'})
# Out:
#                Revenue
# Month_ID
# 11        11255.454545
# 12        11667.806452
# 13         9588.516129
# 14        10683.892857
# 15        10555.354839
# 16        10806.500000
# 17         7636.000000

# %%
temp_ds = ds[['Revenue','Month_ID']].groupby('Month_ID').agg({'Revenue':'sum'}).reset_index()
ax = sns.barplot(x='Month_ID', y='Revenue', data=temp_ds)

# %%
ax = sns.barplot(x='Month_ID', y='Revenue', data=ds, ci=False)

# %%
ax = sns.barplot(x='Month_ID', y='Revenue', data=ds, hue ='Promo', ci=False)

# %%
ax = sns.barplot(x='Revenue', y='Year', data=ds, hue ='Promo', ci=False, orient='h')

# %%
ax = sns.barplot(x='Revenue', y='Year', data=ds, hue ='Promo', ci=False, orient='h', color='#11E5AD')

# %%
ax = sns.barplot(x='Revenue', y='Year', data=ds, hue ='Promo', ci=False, orient='h', palette=['green', 'red', 'blue'])

# %% [markdown]
# # 4. Histograms

# %%
sns.displot(x=ds['Revenue'].values, color='blue')

# %%
sns.displot(x=ds['Revenue'].values, color='blue')
mean = ds['Revenue'].mean()
plt.axvline(mean,0,1, color='red')

# %%
mean = ds['Visitors'].mean()
x = ds['Visitors'].values

sns.displot(x, color='red')
plt.axvline(mean,0,1, color='black')

# %% [markdown]
# # 5. Box Plots

# %%
sns.boxplot(x=ds['Revenue'].values)

# %%
ax = sns.boxplot(x='Day_Name',y='Revenue', data=ds)

# %%
ax = sns.boxplot(x='Revenue',y='Day_Name', data=ds, color='#D37CF7')

# %%
ax = sns.boxplot(x='Day_Name',y='Revenue', data=ds,hue='Promo', color='green')

# %%
ax = sns.boxplot(x='Day_Name', y='Revenue', data=ds, color='#F4EF61')
ax = sns.swarmplot(x='Day_Name', y='Revenue', data=ds, color='red') #all data points

# %% [markdown]
# # 6. ScatterPlots

# %%
ax = sns.scatterplot(x='Marketing Spend', y='Revenue', data=ds, color='green')

# %%
ax = sns.scatterplot(x='Marketing Spend', y='Revenue', data=ds, hue='Promo', style='Promo')

# %%
ax = sns.scatterplot(x='Marketing Spend', y='Visitors', data=ds, hue='Promo', style='Promo', size='Revenue', sizes=(20,200))

# %%
ax = sns.scatterplot(x='Marketing Spend', y='Visitors', data=ds, hue='Day_Name', size='Revenue', sizes=(20,200))

# %% [markdown]
# # 7. lmPlots

# %%
ax = sns.lmplot(x='Marketing Spend', y='Revenue', data=ds, height=10)

# %%
ax = sns.lmplot(x='Marketing Spend', y='Revenue', data=ds, height=10, hue='Promo', ci=None, markers=['o', 'x', '+'])

# %%
ax = sns.lmplot(x='Marketing Spend', y='Revenue', data=ds, height=5, col='Promo', ci=None, line_kws={'color':'red'}, scatter_kws={'color':'#61AAF4'})

# %%
ax = sns.lmplot(x='Marketing Spend', y='Revenue', data=ds, height=5, col='Day_Name', ci=None,
                line_kws={'color':'red'},
                scatter_kws={'color':'green'},
                col_wrap=3)

# %% [markdown]
# # 8. SubPlots

# %%
fig, axis = plt.subplots(2,2,figsize=(12,7))
sns.distplot(ds['Revenue'].values, ax=axis[0,0])
sns.distplot(ds['Visitors'].values, ax=axis[0,1])
sns.distplot(ds['Marketing Spend'].values, ax=axis[1,0])
ax = sns.boxplot(x='Revenue', y='Day_Name', data=ds, color='#abfa80')
ax = sns.swarmplot(x='Revenue', y='Day_Name', data=ds, color='blue')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# # 9. Pairplots

# %%
g = sns.pairplot(ds, plot_kws={'color':'green'})

# %%
g = sns.pairplot(ds.loc[:,'Visitors':'Marketing Spend'], plot_kws={'color':'green'}, height=7)

# %%
ds.columns
# Out:
# Index(['Date', 'Week', 'Week_ID', 'Month', 'Month_ID', 'Year', 'Day_Name',
#        'Visitors', 'Revenue', 'Marketing Spend', 'Promo'],
#       dtype='object')

# %%
g = sns.pairplot(ds.loc[:,'Visitors':'Promo'], height=5, hue='Promo')

# %%
g = sns.pairplot(ds.loc[:,'Visitors':'Promo'], height=5, hue='Promo', kind='reg')

# %% [markdown]
# # 10. JointPlots

# %%
ax = sns.jointplot(x='Marketing Spend', y='Revenue',data=ds, height=10, kind='reg')

# %% [markdown]
# # 11. HeatMap

# %%
cor_ds = ds.loc[:, 'Visitors':'Marketing Spend'].corr()
cor_ds
# Out:
#                  Visitors   Revenue  Marketing Spend
# Visitors         1.000000  0.573842         0.824810
# Revenue          0.573842  1.000000         0.790425
# Marketing Spend  0.824810  0.790425         1.000000

# %%
hm = sns.heatmap(cor_ds, annot=True, annot_kws={'size':50})

# %%
hm = sns.heatmap(cor_ds, annot=True, annot_kws={'size':50}, cmap='Greens')

# %%
hm = sns.heatmap(cor_ds, annot=True, annot_kws={'size':50}, cmap='BuPu')
